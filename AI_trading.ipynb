# %% [markdown]
# <a href="https://colab.research.google.com/github/keeprich/AI-Trading-Bot/blob/main/AI_trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tpqoax
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.3 MB/s eta 0:00:00
# ...
#   Created wheel for v20: filename=v20-3.0.25.0-py3-none-any.whl size=85779 sha256=9031656f9ac16adab0cd610e3c037488e2a017e18c7078ab366b37b4919d23b2
#   Stored in directory: /root/.cache/pip/wheels/b0/29/eb/a94c164f6f87baab5373759f42875082750a38f7efbee5de4f
# Successfully built v20
# ...

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.get_account_summary()
# Out:
# {'id': '101-004-30239848-002',
#  'alias': 'USD_Account',
#  'currency': 'USD',
#  'balance': '100000.0',
#  'createdByUserID': 30239848,
#  'createdTime': '2024-11-02T16:57:45.100432163Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '0.0',
#  'resettablePL': '0.0',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.03333333333333',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '100000.0',
#  'marginUsed': '0.0',
#  'marginAvailable': '100000.0',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '100000.0',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '100000.0',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '5'}

# %%
api.account_type
# Out:
# 'practice'

# %%
api.account_id
# Out:
# '101-004-30239848-002'

# %%
api.get_instruments()
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('CAD/SGD', 'CAD_SGD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('China A50', 'CN50_USD'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Copper', 'XCU_USD'),
#  ('Corn', 'CORN_USD'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('EUR/TRY', 'EUR_TRY'),
# ...

# %%
instra = api.get_instruments()

# %%
len(instra)
# Out:
# 123

# %%
instra[0]
# Out:
# ('AUD/CAD', 'AUD_CAD')

# %%
instra[0][1]
# Out:
# 'AUD_CAD'

# %%
# Get historical Data

help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price, localize=True) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
# ...
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask), 'B' (bid) or 'M' (middle)
#
#     Returns
# ...
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history(instrument=instra[0][1], start="2020-07-01", end="2024-07-31", granularity="D", price="B")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-06-30 21:00:00  0.93665  0.94164  0.93469  0.93937  135264      True
# 2020-07-01 21:00:00  0.93911  0.94282  0.93835  0.93930  143144      True
# 2020-07-02 21:00:00  0.93876  0.94230  0.93797  0.93938  100603      True
# 2020-07-05 21:00:00  0.93956  0.94593  0.93817  0.94398  115000      True
# 2020-07-06 21:00:00  0.94345  0.94759  0.93968  0.94483  133652      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-07-24 21:00:00  0.90830  0.90868  0.90151  0.90375   76680      True
# 2024-07-25 21:00:00  0.90340  0.90786  0.90305  0.90565   49123      True
# 2024-07-28 21:00:00  0.90535  0.90755  0.90439  0.90713   54426      True
# 2024-07-29 21:00:00  0.90640  0.90838  0.90452  0.90540   60506      True
# 2024-07-30 21:00:00  0.90425  0.90606  0.89730  0.90316   72497      True
#
# [1061 rows x 6 columns]

# %%
df = api.get_history(instrument=instra[0][1], start="2020-07-01", end="2024-07-31", granularity="D", price="B")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1061 entries, 2020-06-30 21:00:00 to 2024-07-30 21:00:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   o         1061 non-null   float64
#  1   h         1061 non-null   float64
#  2   l         1061 non-null   float64
#  3   c         1061 non-null   float64
#  4   volume    1061 non-null   int64
#  5   complete  1061 non-null   bool
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 50.8 KB

# %%
api.get_history(instrument=instra[0][1], start="2020-07-01", end="2024-07-31", granularity="D", price="A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-06-30 21:00:00  0.93767  0.94185  0.93498  0.93989  135264      True
# 2020-07-01 21:00:00  0.94024  0.94319  0.93929  0.93997  143144      True
# 2020-07-02 21:00:00  0.94076  0.94283  0.93866  0.94138  100603      True
# 2020-07-05 21:00:00  0.94098  0.94628  0.93997  0.94450  115000      True
# 2020-07-06 21:00:00  0.94488  0.94788  0.93994  0.94545  133652      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-07-24 21:00:00  0.90891  0.90921  0.90197  0.90391   76680      True
# 2024-07-25 21:00:00  0.90436  0.90805  0.90349  0.90606   49123      True
# 2024-07-28 21:00:00  0.90677  0.90772  0.90458  0.90734   54426      True
# 2024-07-29 21:00:00  0.90756  0.90857  0.90478  0.90561   60506      True
# 2024-07-30 21:00:00  0.90631  0.90667  0.89748  0.90338   72497      True
#
# [1061 rows x 6 columns]

# %%
api.get_history(instrument=instra[0][1], start="2020-07-01", end="2024-07-31", granularity="M1", price="B")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-07-01 00:00:00  0.93652  0.93676  0.93635  0.93663     156      True
# 2020-07-01 00:01:00  0.93663  0.93671  0.93653  0.93655     120      True
# 2020-07-01 00:02:00  0.93656  0.93656  0.93619  0.93626     152      True
# 2020-07-01 00:03:00  0.93628  0.93630  0.93605  0.93610     125      True
# 2020-07-01 00:04:00  0.93611  0.93613  0.93595  0.93598     132      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-07-30 23:56:00  0.90599  0.90603  0.90594  0.90594      27      True
# 2024-07-30 23:57:00  0.90594  0.90599  0.90589  0.90590      29      True
# 2024-07-30 23:58:00  0.90586  0.90586  0.90562  0.90562      30      True
# 2024-07-30 23:59:00  0.90563  0.90563  0.90554  0.90556      35      True
# 2024-07-31 00:00:00  0.90560  0.90577  0.90553  0.90573      72      True
#
# [1507890 rows x 6 columns]

# %%
api.get_history(instrument=instra[0][1], start="2024-07-31", end="2024-07-31", granularity="D", price="B")
# Out:
#                            o        h       l        c  volume  complete
# time
# 2024-07-30 21:00:00  0.90425  0.90606  0.8973  0.90316   72497      True

# %%
api.get_history(instrument=instra[0][1], start="2024-07-31", end="2024-07-31", granularity="D", price="A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2024-07-30 21:00:00  0.90631  0.90667  0.89748  0.90338   72497      True

# %% [markdown]
# # Streeming Real time data

# %%
api.stream_data("EUR_USD", stop=10)

# the stop provide the number of data before it stops collecting. If its removed, then the data collection will be in an infinate loop
# Out:
# 2024-11-01T20:59:05.181271376Z 1.08332 1.08339
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-be7b8b5c9ffd> in <cell line: 1>()
# ----> 1 api.stream_data("EUR_USD", stop=10)
#
# /usr/local/lib/python3.10/dist-packages/tpqoa/tpqoa.py in stream_data(self, instrument, stop, ret, callback)
#     344             instruments=instrument)
#     345         msgs = []
# --> 346         for msg_type, msg in response.parts():
#     347             msgs.append(msg)
#     348             # print(msg_type, msg)
#
# /usr/local/lib/python3.10/dist-packages/v20/response.py in parts(self)
#      50
#      51         try:
# ---> 52             for line in self.lines:
#      53                 yield parser(line)
#      54         except requests.exceptions.ConnectionError:
#
# ...

# %%
api.stream_data("EUR_USD")
# Out:
# 2024-11-01T20:59:05.181271376Z 1.08332 1.08339
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-4cd267e37054> in <cell line: 1>()
# ----> 1 api.stream_data("EUR_USD")
#
# /usr/local/lib/python3.10/dist-packages/tpqoa/tpqoa.py in stream_data(self, instrument, stop, ret, callback)
#     344             instruments=instrument)
#     345         msgs = []
# --> 346         for msg_type, msg in response.parts():
#     347             msgs.append(msg)
#     348             # print(msg_type, msg)
#
# /usr/local/lib/python3.10/dist-packages/v20/response.py in parts(self)
#      50
#      51         try:
# ---> 52             for line in self.lines:
#      53                 yield parser(line)
#      54         except requests.exceptions.ConnectionError:
#
# ...

# %%
api.stop_stream()

# %%
# prompt: can i use api.stream_data to direct all streaming data into a file

def stream_data_to_file(instrument, filename="stream_data.csv"):
  """
  Streams real-time data for the given instrument and saves it to a CSV file.

  Args:
    instrument: The instrument to stream data for (e.g., "EUR_USD").
    filename: The name of the CSV file to save the data to.
  """
  def on_success(time, bid, ask):
    with open(filename, "a") as f:
      f.write(f"{time},{bid},{ask}\n")
      print(f"Streamed data: {time}, {bid}, {ask}")

  api.stream_data(instrument, callback=on_success)

# Example usage
stream_data_to_file("EUR_USD", filename="my_stream_data.csv")

# To stop the streaming, you can use api.stop_stream() when needed

# %% [markdown]
# # Create order

# %%
api.create_order(instrument="EUR_USD", units=1000, sl_distance=0.1)
# Out:
#  {'id': '12', 'time': '2024-11-03T11:02:03.769109615Z', 'userID': 30239848, 'accountID': '101-004-30239848-002', 'batchID': '12', 'requestID': '61301991088124884', 'type': 'MARKET_ORDER', 'instrument': 'EUR_USD', 'units': '1000.0', 'timeInForce': 'FOK', 'positionFill': 'DEFAULT', 'reason': 'CLIENT_ORDER', 'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}}

# %%
api.get_transactions()
# Out:
# [{'id': '1',
#   'time': '2024-11-02T16:57:45.100432163Z',
#   'userID': 30239848,
#   'accountID': '101-004-30239848-002',
#   'batchID': '1',
#   'requestID': '1718626381086115616',
#   'type': 'CREATE',
#   'divisionID': 4,
#   'siteID': 101,
#   'accountUserID': 30239848,
#   'accountNumber': 2,
#   'homeCurrency': 'USD'},
#  {'id': '2',
#   'time': '2024-11-02T16:57:45.100432163Z',
#   'userID': 30239848,
#   'accountID': '101-004-30239848-002',
#   'batchID': '1',
#   'requestID': '1718626381086115616',
#   'type': 'CLIENT_CONFIGURE',
#   'alias': 'USD_Account',
#   'marginRate': '0.03333333333333'},
#  {'id': '3',
#   'time': '2024-11-02T16:57:47.128030891Z',
#   'userID': 30239848,
#   'accountID': '101-004-30239848-002',
#   'batchID': '3',
#   'requestID': '1682597584075540080',
#   'type': 'TRANSFER_FUNDS',
#   'amount': '100000.0',
#   'fundingReason': 'ADJUSTMENT',
#   'accountBalance': '100000.0'},
#  {'id': '4',
#   'time': '2024-11-03T08:08:09.540390771Z',
# ...

# %%
api.get_positions()
# Out:
# []

# %% [markdown]
# # Close the order use '-'

# %%
api.create_order(instrument="EUR_USD", units=-1000, sl_distance=0.1)
# Out:
#  {'id': '18', 'time': '2024-11-03T11:02:25.295574722Z', 'userID': 30239848, 'accountID': '101-004-30239848-002', 'batchID': '18', 'requestID': '61301991180404549', 'type': 'MARKET_ORDER', 'instrument': 'EUR_USD', 'units': '-1000.0', 'timeInForce': 'FOK', 'positionFill': 'DEFAULT', 'reason': 'CLIENT_ORDER', 'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}}

# %%
api.print_transactions()
